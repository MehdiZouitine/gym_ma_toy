# %%
import gym_ma_toy
import gym

# %%
env = gym.make("team_catcher-v0")

# %%
env = gym_ma_toy.envs.TeamCatcher(grid_size = 10, nb_agents = 4, nb_targets = 8, seed= 42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-bf0bddf2cb71> in <module>
# ----> 1 env = gym_ma_toy.envs.TeamCatcher(grid_size = 10, nb_agents = 4, nb_targets = 8, seed= 42)
#
# AttributeError: module 'gym_ma_toy' has no attribute 'envs'

# %%
obs = env.reset()
done = False
while not done:
    env.render()
    a = input("")
    obs, reward, done, info = env.step(env.action_space.sample())
# Out:
#  a
#  a
#  a
#  a
#  a
#  a
#  a
